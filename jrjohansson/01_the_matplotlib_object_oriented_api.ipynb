# %% [markdown]
# ### The matplotlib object-oriented API

# %%
# %config IPCompleter.greedy = True

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %%
fig_i = plt.figure()

axes_i = fig_i.add_axes([0.1, 0.1, 1, 1])

axes_i.plot(x, y)

axes_i.set_xlabel('X')
axes_i.set_xlabel('Y')
# Out:
# Text(0.5,0,'Y')

# %%
fig_ii = plt.figure()

axes_ii_a = fig_ii.add_axes([0.1, 0.1, 1, 1])
axes_ii_b = fig_ii.add_axes([0.2, 0.6, 0.5, 0.3])

axes_ii_a.plot(x, y, 'r')

axes_ii_a.set_xlabel('X')
axes_ii_a.set_ylabel('Y')
axes_ii_a.set_title('X ** Y curve')

axes_ii_b.plot(y, x, 'b')

axes_ii_b.set_xlabel('x')
axes_ii_b.set_ylabel('y')
axes_ii_b.set_title('y ** x curve')
# Out:
# Text(0.5,1,'y ** x curve')

# %% [markdown]
# ----

# %% [markdown]
# *If we don't care about beng explicit about where our plot axes are placed in figure canvas then we can use one of many axes lauout managers in matplotlib.*

# %%
fig_iii, axes_iii = plt.subplots(nrows = 1, ncols = 1)

axes_iii.plot(x, y)
axes_iii.set_xlabel('x')
axes_iii.set_ylabel('y')
axes_iii.set_title('x ** y curve using subplots')
# Out:
# Text(0.5,1,'x ** y curve using subplots')

# %%
fig_iv, axes_iv = plt.subplots(nrows = 1, ncols = 2)

for ax in axes_iv:
    ax.plot(x, y)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('x ** y curve using subplots')

fig_iv.tight_layout()
